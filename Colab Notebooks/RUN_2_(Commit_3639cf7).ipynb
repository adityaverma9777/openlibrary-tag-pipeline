# %%
# !git clone https://github.com/adityaverma9777/openlibrary-tag-pipeline.git
# %cd openlibrary-tag-pipeline
# Out:
# Cloning into 'openlibrary-tag-pipeline'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 6), reused 27 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 32.90 KiB | 3.66 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/openlibrary-tag-pipeline

# %%
# !pip install -r requirements.txt
# !pip install torch transformers faiss-cpu umap-learn
# Out:
# ...
#   Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# ...
# Using cached faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
# ...

# %%
import torch
print("GPU:", torch.cuda.is_available())
# Out:
# GPU: True

# %%
# !python demo.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   organized crime                         —
#   mafia                                   —
#   cartel                                  —
#   yakuza                                  —
#   triad                                   —
#   thriller                                —
#   suspense                                —
#   action                                  —
#   adventure                               —
#   survival                                —
#   treasure hunt                           —
#   swashbuckler                            —
#   pirates                                 —
#   romance                                 —
#   love story                              —
#   love                                    —
#   romantic                                —
#   contemporary romance                    —
#   historical romance                      —
#   paranormal romance                      —
# ...
